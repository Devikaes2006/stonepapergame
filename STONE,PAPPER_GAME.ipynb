# %% [markdown]
# <a href="https://colab.research.google.com/github/Devikaes2006/stonepapergame/blob/main/STONE%2CPAPPER_GAME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
title=("** WELCOME TO STONE PAPER SCISSOR GAME **")    #level 1
print(title)
user_input=input("enter stone paper scissor:")
computer_choice="paper"                      # level 2
print("computer choice:",computer_choice)
print("user input:",user_input)
if user_input==computer_choice:   #level 3
   print("match draw!")
elif user_input=="scissor":
   print("you win!")
else:
  print("computer win!")
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# enter stone paper scissor:paper
# computer choice: paper
# user input: paper
# match draw!

# %%
title=("** WELCOME TO STONE PAPER SCISSOR GAME **")    #level 1
print(title)
user_input=input("enter stone paper scissor:")
computer_choice="paper"                      # level 2
print("computer choice:",computer_choice)
print("user input:",user_input)
if user_input==computer_choice:   #level 3
   print("match draw!")
elif (user_input=="stone" and computer_choice=="scissor")or\   # level 4
  (user_input=="paper" and computer_choice=="stone")or\
  (user_input=="scissor" and computer_choice=="paper"):
  print("you win")
else:
    print("computer win")
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# enter stone paper scissor:stone
# computer choice: paper
# user input: stone
# computer win

# %%
title=("** WELCOME TO STONE PAPER SCISSOR GAME **")      # level 4
print(title)
user_input=input("enter stone paper scissor:")
computer_choice="paper"
print("computer choice:",computer_choice)
print("user input:",user_input)
if user_input==computer_choice:
   print("match draw!")
elif (user_input=="stone" and computer_choice=="scissor")or(user_input=="paper" and computer_choice=="stone")or(user_input=="scissor" and computer_choice=="paper"):
  print("you win")
else:
    print("computer win")
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# enter stone paper scissor:stone
# computer choice: paper
# user input: stone
# computer win

# %%
import random   #............
print("** WELCOME TO STONE PAPER SCISSOR GAME **")      # level 5
user_input=input("choose stone paper scissor:")
choice=["stone","paper","scissor"]    #........
computer_choice=random.choice(choice)   #.......
print("computer choice:",computer_choice)
print("user input:",user_input)
if user_input==computer_choice:
   print("match draw!")
elif (user_input=="stone" and computer_choice=="scissor")or(user_input=="paper" and computer_choice=="stone")or(user_input=="scissor" and computer_choice=="paper"):
  print("you win")
else:
    print("computer win")
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# choose stone paper scissor:paper
# computer choice: scissor
# user input: paper
# computer win

# %%
import random
print("** WELCOME TO STONE PAPER SCISSOR GAME **")       #level 6
choice=["stone","paper","scissor"]
while True:    #.......
  user_input=input("choose stone paper scissor:")
  if user_input not in choice:
    print("invalid input! please enter stone paper scissor")
    continue  #........
  computer_choice=random.choice(choice)
  print("computer choice:",computer_choice)
  print("user input:",user_input)
  if user_input==computer_choice:
    print("match draw")
  elif (user_input=="stone" and computer_choice=="scissor")or(user_input=="paper" and computer_choice=="stone")or(user_input=="scissor" and computer_choice=="paper"):
   print("you win")
  else:
      print("computer win")
  break   #..........
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# choose stone paper scissor:gfj
# invalid input! please enter stone paper scissor
# choose stone paper scissor:paper
# computer choice: scissor
# user input: paper
# computer win

# %%
import random
print("** WELCOME TO STONE PAPER SCISSOR GAME **")       #level 7
choice=["stone","paper","scissor"]
while True:
  user_input=input("choose stone paper scissor:")
  if user_input not in choice:
    print("invalid input! please enter stone paper scissor")
    continue
  computer_choice=random.choice(choice)
  print("computer choice:",computer_choice)
  print("user input:",user_input)
  if user_input==computer_choice:
    print("match draw")
  elif (user_input=="stone" and computer_choice=="scissor")or(user_input=="paper" and computer_choice=="stone")or(user_input=="scissor" and computer_choice=="paper"):
   print("you win")
  else:
      print("computer win")
  play_again=input("do you want to play again?(yes/no)")  #.......
  if play_again!="yes":  #......
     print("thank you!")#.......
     break
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# choose stone paper scissor:dhd
# invalid input! please enter stone paper scissor
# choose stone paper scissor:stone
# computer choice: scissor
# user input: stone
# you win
# do you want to play again?(yes/no)yes
# choose stone paper scissor:stone
# computer choice: stone
# user input: stone
# match draw
# do you want to play again?(yes/no)no
# thank you!

# %%
import random
print("** WELCOME TO STONE PAPER SCISSOR GAME **")       #level 8
choice=["stone","paper","scissor"]
while True:
  try:   #........
    user_input=input("choose stone paper scissor:")
    if user_input not in choice:
      print("invalid input! please enter stone paper scissor")
      continue
    computer_choice=random.choice(choice)
    print("computer choice:",computer_choice)
    print("user input:",user_input)
    if user_input==computer_choice:
       print("match draw")
    elif (user_input=="stone" and computer_choice=="scissor")or(user_input=="paper" and computer_choice=="stone")or(user_input=="scissor" and computer_choice=="paper"):
      print("you win")
    else:
      print("computer win")
  except ValueError:#.........
    print("error!")  #............
  play_again=input("do you want to play again?(yes/no)")
  if play_again!="yes":
      print("thank you!")
      break
# Out:
# ** WELCOME TO STONE PAPER SCISSOR GAME **
# choose stone paper scissor:fdhi
# invalid input! please enter stone paper scissor
# choose stone paper scissor:stone
# computer choice: paper
# user input: stone
# computer win
# do you want to play again?(yes/no)yes
# choose stone paper scissor:stone
# computer choice: paper
# user input: stone
# computer win
# do you want to play again?(yes/no)no
# thank you!
